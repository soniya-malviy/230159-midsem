# %% [markdown]
# # Task 4.2 — LLM Usage Disclosure
#
# All LLM usage disclosure files are stored as JSON:
#
# - `partB/llm_task_1_1.json` through `partB/llm_task_4_2.json`
#
# This notebook contains no code — see the JSON files for full disclosure.

# %%
import os
jsons = [f for f in os.listdir('partB/') if f.startswith('llm_')]
print(f'{len(jsons)} LLM disclosure files found:')
for j in sorted(jsons): print(f'  {j}')
# Out:
# 10 LLM disclosure files found:
#   llm_task_1_1.json
#   llm_task_1_2.json
#   llm_task_1_3.json
#   llm_task_2_1.json
#   llm_task_2_2.json
#   llm_task_2_3.json
#   llm_task_3_1.json
#   llm_task_3_2.json
#   llm_task_4_1.json
#   llm_task_4_2.json
