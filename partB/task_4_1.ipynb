# %% [markdown]
# # Task 4.1 — Report
#
# The report for Part B is contained in `partB/report.pdf`.
#
# This notebook contains no code — see report.pdf for the full written synthesis.

# %%
print('Report: see partB/report.pdf')
# Out:
# Report: see partB/report.pdf
